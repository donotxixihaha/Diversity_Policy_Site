# %%
import pandas as pd
import requests # 2
import json # 3

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
df = pd.read_csv("./policies_link_refined.csv", header=0)
df.head()
# Out:
#       id       timestamp                                             title  \
# 0  21103   8/2/2019 9:48   Economics\tDepartment:\tSummer\tSession\tPolicy
# 1  21104  8/2/2019 13:39          Compensation and Benefits--Compensation
# 2  21105  8/2/2019 13:40  Compensation and Benefits--Excused Days With Pay
# 3  21106  8/2/2019 13:40       Compensation and Benefits--Leave of Absence
# 4  21107  8/2/2019 13:41               Compensation and Benefits--Benefits
#
#                                school  \
# 0                university of oregon
# 1  university of massachusetts lowell
# 2  university of massachusetts lowell
# 3  university of massachusetts lowell
# 4  university of massachusetts lowell
#
#                                    department administrator author  \
# 0                                         NaN           NaN    NaN
# 1  UNIVERSITY OF MASSACHUSETTS MEDICAL SCHOOL           NaN    NaN
# 2  UNIVERSITY OF MASSACHUSETTS MEDICAL SCHOOL           NaN    NaN
# ...

# %%
# Google Maps API Key
ggeocode = "" # TODO Enter your API Key here

# %%
df.loc[df['latitude']=="Statement of Principles",['latitude']] = "39.7089194"
df.loc[df['latitude']=="Student Sexual Misconduct and Harassment Policy",['latitude']] = "39.7089235"
df.loc[df['latitude'].str.startswith("This is an exciting time for the University of"),['latitude']] = "42.2780475"

df.loc[df['latitude'].str.startswith("Scope of University Authority for Violations"),['latitude']] = "64.8557589"
df.loc[df.index==5753,"latitude"] = "39.3299054"
df.loc[df.index==4113,"latitude"] = "42.7297667"
df.loc[df.index==3097,"latitude"] = "40.9123761"
df.loc[df.index==3426,"latitude"] = "42.2780475"
df.loc[df.index==3432,"latitude"] = "42.2780475"
df.loc[df.index==6366,"latitude"] = "39.1754528"
df.loc[df.index==9858,"latitude"] = "40.7448519"
df.loc[df.index==19289,"latitude"] = "33.9937619"


df.loc[df.index==704, "longitude"] = "75.1204621"
df.loc[df.index==4113, "longitude"] = "73.6810771"
df.loc[df.index==5753, "longitude"] = "76.6227064"

df.loc[df['longitude'].str.startswith("https://conf"),['longitude']] = "-75.1204621"
df.loc[df['longitude'].str.startswith("http://www.sc"),['longitude']] = "-81.0321073"

df["latitude"] = df["latitude"].replace('Latitude: ', '', regex=True)
df["latitude"] = df["latitude"].replace('a\.\\t', '', regex=True)

df["longitude"] = df["longitude"].replace('Longitude: ', '', regex=True)
df["longitude"] = df["longitude"].replace('=', '', regex=True)

df.loc[df.index==819, "longitude"] = "111.8421"


df.loc[df['school'] == "the university of montana western","latitude"] = "45.2087889"
df.loc[df['school'] == "the university of montana western","longitude"] = "112.6409367"

df.loc[df['school'] == "university of michigan","latitude"] = "42.2780475"
df.loc[df['school'] == "university of michigan","longitude"] = "83.7404128"

df.loc[df['school'] == "temple university","latitude"] = "39.9805983"
df.loc[df['school'] == "temple university","longitude"] = "75.1579263"

df.loc[df.index==12585, "latitude"] = "39.132926"

df.loc[df.index==18077, "longitude"] = "87.9307554"

df.loc[df.index==20281, "longitude"] = "83.0309"

df.loc[df['school'] == "the university of california riverside","latitude"] = "33.9737099"
df.loc[df['school'] == "the university of california riverside","longitude"] = "117.3302531"

df.loc[df['school'] == "mississippi state university","latitude"] = "33.4551787"
df.loc[df['school'] == "mississippi state university","longitude"] = "88.7965653"


df.loc[df.index==1539, "latitude"] = "40.0093"

df.loc[df.index==2809, "longitude"] = "86.8027"

df.loc[df.index==3055, "longitude"] = "118.2851"

df.loc[df.index==3387, "latitude"] = "36.1352"
df.loc[df.index==3387, "longitude"] = "80.2763"

df.loc[df.index==3801, "latitude"] = "40.6520"
df.loc[df.index==3801, "longitude"] = "75.5742"

df.loc[df.index==4030, "longitude"] = "71.1167"

df.loc[df.index==4420, "latitude"] = "41.8077"
df.loc[df.index==4420, "longitude"] = "72.2540"

df.loc[df.index==4803, "latitude"] = "38.9869"
df.loc[df.index==4803, "longitude"] = "76.9426"

df.loc[df.index==4880, "latitude"] = "36.1085"
df.loc[df.index==4880, "longitude"] = "115.1432"


df.loc[df.index==6429, "latitude"] = "39.1673"
df.loc[df.index==6429, "longitude"] = "86.5214"

df.loc[df.index==6913, "latitude"] = "38.9869"
df.loc[df.index==6913, "longitude"] = "76.9426"

df.loc[df.index==6927, "latitude"] = "38.9869"
df.loc[df.index==6927, "longitude"] = "76.9426"


df.loc[df['school'] == "biola university","latitude"] = "33.905452"
df.loc[df['school'] == "biola university","longitude"] = "118.0173684"


df.loc[df['school'] == "the university of montana","latitude"] = "46.8600708"
df.loc[df['school'] == "the university of montana","longitude"] = "113.9873968"


df.loc[df.index==9165, "latitude"] = "36.0678"
df.loc[df.index==9165, "longitude"] = "94.1737"

df.loc[df.index==9858, "latitude"] = "40.7448"
df.loc[df.index==9858, "longitude"] = "74.0256"


df.loc[df.index==9986, "latitude"] = "39.5105"
df.loc[df.index==9986, "longitude"] = "84.7309"

df.loc[df.index==10370, "latitude"] = "43.0846"
df.loc[df.index==10370, "longitude"] = "77.6743"

df.loc[df.index==11069, "latitude"] = "40.7649"
df.loc[df.index==11069, "longitude"] = "111.8421"

df.loc[df.index==11299, "latitude"] = "42.0266"
df.loc[df.index==11299, "longitude"] = "93.6465"

df.loc[df.index==12191, "latitude"] = "38.9369"
df.loc[df.index==12191, "longitude"] = "76.9987"

df.loc[df.index==12300, "latitude"] = "32.7757"
df.loc[df.index==12300, "longitude"] = "117.0719"

df.loc[df.index==12905, "latitude"] = "41.8698"
df.loc[df.index==12905, "longitude"] = "87.6496"

df.loc[df['school'] == "the university of rhode island","school"] = "university of rhode island"
df.loc[df['school'] == "university of rhode island","latitude"] = "41.4861"
df.loc[df['school'] == "university of rhode island","longitude"] = "71.5309"


df.loc[df.index==13743, "latitude"] = "28.0587"
df.loc[df.index==13743, "longitude"] = "82.4139"

df.loc[df.index==14126, "latitude"] = "44.563782"
df.loc[df.index==14126, "longitude"] = "123.279442"

df.loc[df.index==14764, "latitude"] = "43.0385"
df.loc[df.index==14764, "longitude"] = "87.9304"



df.loc[df['school'] == "virginia commonwealth university","latitude"] = "37.5485"
df.loc[df['school'] == "virginia commonwealth university","longitude"] = "77.4480"

df.loc[df.index==16202, "latitude"] = "39.9566"
df.loc[df.index==16202, "longitude"] = "75.1899"


df.loc[df.index==16892, "latitude"] = "40.8628804435493"
df.loc[df.index==16892, "longitude"] = "74.1972237825394"




df.loc[df.index==17527, "latitude"] = "43.0385"
df.loc[df.index==17527, "longitude"] = "87.9304"



df.loc[df.index==17540, "latitude"] = "39.3244"
df.loc[df.index==17540, "longitude"] = "82.1014"




df.loc[df.index==18026, "latitude"] = "43.0385"
df.loc[df.index==18026, "longitude"] = "87.9304"


df.loc[df.index==20039, "latitude"] = "44.5639"
df.loc[df.index==20039, "longitude"] = "69.6626"


df.loc[df.index==20270, "latitude"] = "34.1061"
df.loc[df.index==20270, "longitude"] = "117.7105"

df.loc[df['school'] == "the university of california davis","latitude"] = "38.5382364"
df.loc[df['school'] == "the university of california davis","longitude"] = "121.7639012"

df.loc[(df['state'] == 'new york') & (df['city'] == 'manhattan'), "city"] = "new york"

df.loc[df['school'] == "immaculata university","latitude"] = "40.0279921"
df.loc[df['school'] == "immaculata university","longitude"] = "75.5728881"


df.loc[df['school'] == "seton hall university","latitude"] = "40.7433813"
df.loc[df['school'] == "seton hall university","longitude"] = "74.2487333"

df.loc[df['school'] == "university of maryland – baltimore county","latitude"] = "39.25568"
df.loc[df['school'] == "university of maryland – baltimore county","longitude"] = "76.7131561"


df.loc[df['school'] == "university of missouri","latitude"] = "38.940385"
df.loc[df['school'] == "university of missouri","longitude"] = "92.3299262"


df.loc[df['school'] == "university at buffalo--suny","latitude"] = "42.9490402"
df.loc[df['school'] == "university at buffalo--suny","longitude"] = "78.8955351"


df.loc[df['school'] == "university of texas - dallas","city"] = "richardson"

df.loc[df['school'] == "fordham university","city"] = "the bronx"

df.loc[df['school'] == "robert morris university","latitude"] = "40.5215552"
df.loc[df['school'] == "robert morris university","longitude"] = "80.2141103"
df.loc[df['school'] == "robert morris university","city"] = "moon"


df.loc[df['school'] == "lesley university","latitude"] = "42.3801832"
df.loc[df['school'] == "lesley university","longitude"] = "71.1195523"

df.loc[df['school'] == "montana state university", "latitude"] = "45.6674983"
df.loc[df['school'] == "montana state university", "longitude"] = "111.0541805"



df.loc[df['school'] == "university of pittsburgh", "latitude"] = "40.4443574"
df.loc[df['school'] == "university of pittsburgh", "longitude"] = "79.9630237"


df.loc[df['school'] == "michigan state university", 'city'] = "lansing"





df.loc[df['school'] == "cornell university", 'city'] = "ithaca"


 
df.loc[df['state'] == "washington d.c.", 'state'] = "district of columbia"
df.loc[df['city'] == "washington d.c.", 'city'] = "washington"

df.loc[df['school'] == "university of north texas at dallas", "latitude"] = "32.6585475"
df.loc[df['school'] == "university of north texas at dallas", "longitude"] = "96.8059072"


df.loc[df['school'] == "university of tulsa", "latitude"] = "36.1520569"
df.loc[df['school'] == "university of tulsa", "longitude"] = "95.948264"



df.loc[df['school'] == "boston college", 'city'] = "chestnut hill"

df.loc[df['school'] == "stony brook university", "latitude"] = "40.9123801"
df.loc[df['school'] == "stony brook university", "longitude"] = "73.1255776"
df.loc[df['school'] == "stony brook university", "city"] = "stony brook"

df.loc[df['school'] == "washington state university", "latitude"] = "46.7314859"
df.loc[df['school'] == "washington state university", "longitude"] = "117.1559757"
df.loc[df['school'] == "washington state university", "city"] = "pullman"

df.loc[(df['school'] == "university of hawaii")&(df['city'] == "manoa"), "city"] = "honolulu"

df.loc[df['school'] == "university of miami", "city"] = "coral gables"

df.loc[df['school'] == "university of wisconsin-madison", "latitude"] = "43.0765959"
df.loc[df['school'] == "university of wisconsin-madison", "longitude"] = "89.4146762"


df.loc[df['school'] == "university of california santa barbara", "city"] = "isla vista"


df.loc[df.index==3443, "city"] = "waltham"


df.loc[df.index==3456, "latitude"] = "33.7756"
df.loc[df.index==3456, "longitude"] = "84.3963"

df.loc[df['school'] == "university of connecticut", "city"] = "storrs"

df.loc[df['school'] == "university of california san diego", "city"] = "la jolla"

df.loc[df['school'] == "university of florida", "latitude"] = "29.6436371"
df.loc[df['school'] == "university of florida", "longitude"] = "82.3571189"
df.loc[df['school'] == "university of florida", "city"] = "gainesville"

df.loc[df['school'] == "oklahoma state university", "latitude"] = "36.1270279"
df.loc[df['school'] == "oklahoma state university", "longitude"] = "97.0759109"
df.loc[df['school'] == "oklahoma state university", "city"] = "stillwater"

df.loc[df['school'] == "pomona college", "city"] = "claremont"
df.loc[df['school'] == "pomona college", "latitude"] = "34.0973127" 
df.loc[df['school'] == "pomona college", "longitude"] = "117.7145033"

df.loc[df['school'] == "bowdoin college", "latitude"] = "43.9088226"
df.loc[df['school'] == "bowdoin college", "longitude"] = "69.9654312"
df.loc[df['school'] == "bowdoin college", "city"] = "brunswick"

df.loc[df['school'] == "massachusetts institute of technology", "city"] = "cambridge"

df.loc[df['school'] == "the university of north carolina at chapel hill", "city"] = "chapel hill"

df.loc[df['school'] == "new jersey institute of technology", "latitude"] = "40.7427233"
df.loc[df['school'] == "new jersey institute of technology", "longitude"] = "74.1794037"

df.loc[df['school'] == "university of georgia", "latitude"] = "33.9480097"
df.loc[df['school'] == "university of georgia", "longitude"] = "83.3795108"

df.loc[df['school'] == "purdue", "latitude"] = "40.4210183"
df.loc[df['school'] == "purdue", "longitude"] = "86.9247472"


df.loc[df['school'] == "southern methodist university", "latitude"] = "32.8412223"
df.loc[df['school'] == "southern methodist university", "longitude"] = "96.7867062"

df.loc[df['school'] == "saint louis university", "latitude"] = "38.6346997"
df.loc[df['school'] == "saint louis university", "longitude"] = "90.2362474"

df.loc[df['school'] == "texas a&m university", "city"] = "college station"


df.loc[df['school'] == "university of washington", "latitude"] = "47.6553387"
df.loc[df['school'] == "university of washington", "longitude"] = "122.3057086"

df.loc[df['school'] == "birmingham southern college", "city"] = "birmingham"

df.loc[df['school'] == "keene state college", "latitude"] = "42.9255545"
df.loc[df['school'] == "keene state college", "longitude"] = "72.2825736"

df.loc[df['school'] == "university of new hampshire at manchester", "latitude"] = "42.9871148"
df.loc[df['school'] == "university of new hampshire at manchester", "longitude"] = "71.4708763"

df.loc[df['school'] == "thomas more college of liberal arts", "state"] = "new hampshire"
df.loc[df['school'] == "thomas more college of liberal arts", "city"] = "merrimack"
df.loc[df['school'] == "thomas more college of liberal arts", "latitude"] = "42.8066325"
df.loc[df['school'] == "thomas more college of liberal arts", "longitude"] = "71.48655"

df.loc[df['school'] == "carrol college", "latitude"] = "46.6007406"
df.loc[df['school'] == "carrol college", "longitude"] = "112.0408774"

df.loc[df['school'] == "truman state university", "latitude"] = "40.183167"
df.loc[df['school'] == "truman state university", "longitude"] = "92.5831508"

df.loc[df['school'] == "logan university", "latitude"] = "38.6312549"
df.loc[df['school'] == "logan university", "longitude"] = "90.5447256"

df.loc[df['school'] == "missouri university of science and technology", "latitude"] = "37.9536757"
df.loc[df['school'] == "missouri university of science and technology", "longitude"] = "91.7778165"

df.loc[df['school'] == "salish kootenai college", "latitude"] = "47.5974886"
df.loc[df['school'] == "salish kootenai college", "longitude"] = "114.1139847"

df.loc[df['school'] == "montana tech of the university of montana", "latitude"] = "46.0116186"
df.loc[df['school'] == "montana tech of the university of montana", "longitude"] = "112.5591856"


df.loc[df['school'] == "rocky mountain college", "latitude"] = "45.7966004"
df.loc[df['school'] == "rocky mountain college", "longitude"] = "108.56034"

df.loc[df.index == 7523, "school"] = "the university of montana western"
df.loc[df.index == 7523, "title"] = "Missing Student"
df.loc[df.index == 7523, "latitude"] = "45.2087927"
df.loc[df.index == 7523, "longitude"] = "112.6409367"

df.loc[df['school'] == "samford university", "latitude"] = "33.4647539"
df.loc[df['school'] == "samford university", "longitude"] = "86.7958197"
df.loc[df['school'] == "samford university", "city"] = "homewood"

df.loc[df['school'] == "american university", "latitude"] = "38.937499"
df.loc[df['school'] == "american university", "longitude"] = "77.0909916"

df.loc[df['school'] == "university of central florida", "latitude"] = "28.6024321"
df.loc[df['school'] == "university of central florida", "longitude"] = "81.2022486"

df.loc[df['school'] == "binghamton university", "latitude"] = "42.0894507"
df.loc[df['school'] == "binghamton university", "longitude"] = "75.971704"

df.loc[df['school'] == "saint louis university", "city"] = "st. louis"

df.loc[df['school'] == "depaul university", "latitude"] = "41.9247599"
df.loc[df['school'] == "depaul university", "longitude"] = "87.6588352"

df.loc[df['school'] == "university of utah", "city"] = "salt lake city"


df.loc[df['school'] == "texas christian university", "city"] = "fort worth"

df.loc[df['school'] == "hofstra university", "latitude"] = "40.7166912"
df.loc[df['school'] == "hofstra university", "longitude"] = "73.6015852"


df.loc[df['school'] == "adelphi university", "state"] = "new york"
df.loc[df['school'] == "adelphi university", "city"] = "garden city"



df.loc[df['school'] == "michigan technological university", "city"] = "houghton"

df.loc[df['school'] == "university of mississippi", "latitude"] = "34.3712502"
df.loc[df['school'] == "university of mississippi", "longitude"] = "89.5551175"


df.loc[df['school'] == "oregon state university", "city"] = "corvallis"


df.loc[df['school'] == "marquette university", "city"] = "milwaukee"

df.loc[df['school'] == "university of cincinnati", "latitude"] = "39.132926"
df.loc[df['school'] == "university of cincinnati", "longitude"] = "84.5171391"


df.loc[df['school'] == "university of kentucky", "latitude"] = "38.0306553"
df.loc[df['school'] == "university of kentucky", "longitude"] = "84.5061584"


df.loc[df['school'] == "the university of mississippi", "latitude"] = "34.3637433"
df.loc[df['school'] == "the university of mississippi", "longitude"] = "89.547753"

df.loc[df['school'] == "university of orlando", "latitude"] = "28.6024321"
df.loc[df['school'] == "university of orlando", "longitude"] = "81.2022486"
df.loc[df['school'] == "university of orlando", "school"] = "university of central florida"

df.loc[df['school'] == "university of central florida", "city"] = "orlando"

df.loc[df['school'] == "university system of maryland", "latitude"] = "39.0034973"
df.loc[df['school'] == "university system of maryland", "longitude"] = "76.96823"
df.loc[df['school'] == "university system of maryland", "city"] = "adelphi"

df.loc[df['school'] == "college of the ozarks", "latitude"] = "36.6163242"
df.loc[df['school'] == "college of the ozarks", "longitude"] = "93.2415676"


df.loc[df['school'] == "dartmouth college", "latitude"] = "43.7044445"
df.loc[df['school'] == "dartmouth college", "longitude"] = "72.2908822"

df.loc[df['school'] == "harvey mudd college", "latitude"] = "34.1060861"
df.loc[df['school'] == "harvey mudd college", "longitude"] = "117.7126586"

df.loc[df['school'] == "st. john's university", "latitude"] = "40.6212629"
df.loc[df['school'] == "st. john's university", "longitude"] = "74.0939785"
df.loc[df['school'] == "st. john's university", "city"] = "staten island"

df.loc[df['school'] == "university of illinois at urbana-champaign", "latitude"] = "40.1019564"
df.loc[df['school'] == "university of illinois at urbana-champaign", "longitude"] = "88.2293502"
df.loc[df['school'] == "university of illinois at urbana-champaign", "city"] = "champaign"


df.loc[df['school'] == "university of alaska fairbanks", "city"] = "fairbanks"

df.loc[df['city'] == "st. paul", "city"] = "st paul"

# %%
# df.loc[df['longitude'].str.startswith("http://www.sc")] 
# df.loc[df["longitude"]=="Oklahoma City",["longitude"]] = "-97.0759109"
df.loc[df.index==66]
# Out:
#        id       timestamp                   title                    school  \
# 66  19335  7/6/2019 23:01  Copyright and Fair Use  university of st. thomas
#
#    department administrator author      state     city   latitude   longitude  \
# 66        NaN           NaN    NaN  minnesota  st paul  44.943939  -93.189888
#
#                                    link published_date            tags  \
# 66  https://www.stthomas.edu/copyright/            NaN  Administrative
#
#    abstract                                               text
# 66      NaN  Skip to primary content\r\nHome\r\nTOGGLE SEAR...

# %%
df["latitude"] = df["latitude"].replace(',.*', '',regex=True).str.lstrip().str.rstrip()
df["longitude"] = df["longitude"].replace('.*,', '',regex=True).str.lstrip().str.rstrip()

df["latitude"] = df["latitude"].replace('°.*', '',regex=True)
df["longitude"] = df["longitude"].replace('°.*', '',regex=True)
df["latitude"] = df["latitude"].replace(' (N|W|w|n)', '',regex=True)
df["longitude"] = df["longitude"].replace(' (W|w|N|n)', '',regex=True)

df["longitude"] = df["longitude"].replace('-','',regex=True)

df["latitude"] = df["latitude"].str.rstrip('.')
df["longitude"] = df["longitude"].str.rstrip('.')

# %%
df.loc[(df['state'] == 'new york') & (df['city'] == 'buffalo')]
# Out:
#          id        timestamp  \
# 1235   8705  2/13/2019 22:47
# 2310   8691  2/13/2019 22:34
# 2313   8692  2/13/2019 22:34
# 2314   8693  2/13/2019 22:36
# 2323   8694  2/13/2019 22:37
# 9581   8690  2/13/2019 22:32
# 9582   8704  2/13/2019 22:46
# 9583   8685  2/13/2019 22:26
# 9584   8686  2/13/2019 22:27
# 9585   8687  2/13/2019 22:28
# 9586   8688  2/13/2019 22:29
# 9587   8689  2/13/2019 22:31
# 9589   8695  2/13/2019 22:38
# 9590   8696  2/13/2019 22:39
# 9591   8697  2/13/2019 22:40
# 9592   8698  2/13/2019 22:40
# 9593   8699  2/13/2019 22:42
# 9594   8700  2/13/2019 22:42
# 9595   8701  2/13/2019 22:43
# 9596   8702  2/13/2019 22:44
# 9597   8703  2/13/2019 22:45
# 9598   8706  2/13/2019 22:48
# 9951   9240  2/24/2019 12:06
# 9961   9255  2/24/2019 13:06
# 9989   9241  2/24/2019 12:02
# 9993   9244  2/24/2019 12:55
# 9994   9245  2/24/2019 12:07
# 9995   9246  2/24/2019 12:09
# 10002  9250  2/24/2019 12:59
# 10003  9251  2/24/2019 13:00
# 10004  9252  2/24/2019 13:01
# ...

# %%
df.loc[df['school'] == "university of st. thomas"]
# Out:
#           id       timestamp  \
# 66     19335  7/6/2019 23:01
# 883    19336  7/6/2019 23:02
# 2609   19363   7/7/2019 0:36
# 4708   18680  6/30/2019 1:54
# 6585   19894  7/14/2019 5:07
# ...      ...             ...
# 19166  20308  7/21/2019 0:23
# 19177  20324  7/21/2019 1:15
# 19181  20329  7/21/2019 1:21
# 19182  20330  7/21/2019 1:22
# 19184  20332  7/21/2019 1:29
#
#                                                    title  \
# 66                                Copyright and Fair Use
# 883                         UST Research Online Policies
# 2609                              Online Privacy Policy
# 4708                                      Data Security
# 6585      II. POLICIES REGARDING ALCOHOL AND OTHER DRUGS
# ...                                                  ...
# 19166                                   Cost Information
# 19177  Refund Schedule - Graduate, Law, and Professio...
# 19181                                       Campus Store
# ...

# %%
# df_lat = df['latitude'].replace('\.','',regex=True)
# df_lat.loc[~(df_lat.str.isnumeric())]

# df_log = df['longitude'].replace('\.','',regex=True).replace('-','',regex=True)
# df_log.loc[~(df_log.str.isnumeric())]

# %%
df_geo = df[['state', 'city', 'latitude', 'longitude']].drop_duplicates()
df_geo.head()
# Out:
#             state       city    latitude  longitude
# 0          oregon     eugene     44.0448   123.0726
# 1   massachusetts     lowell   42.642716  71.334530
# 7      new jersey  glassboro     39.7099    75.1189
# 8            utah      provo     40.2518   111.6493
# 13     new jersey  glassboro  39.7089194    75.1189

# %%
def validate_geo(state, city, lat, lng): # 4
    """Get the state and city for the geo data."""
    # Define the base url
    #   https://maps.googleapis.com/maps/api/geocode/json?latlng=40.714224,-73.961452&key=AIzaSyA2fl1w99v9hxk0LL4ryYm8xdZwy-R8xnE
    geo_url = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={lat},-{lng}&key={ggeocode}" # 6
    response = requests.get(geo_url) # 7
    content = response.content.decode("utf8") # 8
    geo_js = json.loads(content) # 9
    geo_status = geo_js["status"] # 10
    if geo_status == "OK": # 11
        if 'formatted_address' in geo_js["results"][0]:
            geo_elements = geo_js["results"][0]["formatted_address"] # 12
        else:
            print(None)
            return None
        address = geo_elements.split(", ")
#         print(address)
        city_true = address[-3].lower()
        state_true = states[address[-2].split(" ")[0]].lower()
#         print(city_true, state_true, city, state)
        if city == city_true and state == state_true:
#             print(True)
            return True
        else:
#             print(False)
            return False
    else: # 18
#         print(None)
        return None
#         print(f"Long/lat coordinates unavailable.") # 21

# %%
df_geo['geo_validation'] = df_geo.apply(lambda row: validate_geo(row['state'], row['city'], row['latitude'], row['longitude']),axis=1)

# %%
df_geo.loc[df_geo['geo_validation']==False]
# Out:
#          state        city    latitude  longitude geo_validation
# 9956  new york  binghamton  42.0894507  75.971704          False

# %%
validate_geo(df_geo['state'][18108], df_geo['city'][18108], df_geo['latitude'][18108], df_geo['longitude'][18108])
# Out:
# True

# %%
df.to_csv("./policies_geo_refined.csv", encoding='utf-8', index=False)

# %% [markdown]
# #
